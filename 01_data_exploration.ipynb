# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.read_csv(r"C:\Users\KASHISH\Downloads\air quality dataset\data\data_date.csv")
# Out:
#              Date                   Country                          Status  \
# 0      2022-07-21                   Albania                            Good
# 1      2022-07-21                   Algeria                        Moderate
# 2      2022-07-21                   Andorra                        Moderate
# 3      2022-07-21                    Angola  Unhealthy for Sensitive Groups
# 4      2022-07-21                 Argentina                        Moderate
# ...           ...                       ...                             ...
# 20963  2025-09-04  United States of America                        Moderate
# 20964  2025-09-04                Uzbekistan                            Good
# 20965  2025-09-04                   Vatican                            Good
# 20966  2025-09-04                 Venezuela                            Good
# 20967  2025-09-04                   Vietnam                            Good
#
#        AQI Value
# 0             14
# 1             65
# ...

# %%
df= pd.read_csv(r"C:\Users\KASHISH\Downloads\air quality dataset\data\data_date.csv")

# %%
df.head()
# Out:
#          Date    Country                          Status  AQI Value
# 0  2022-07-21    Albania                            Good         14
# 1  2022-07-21    Algeria                        Moderate         65
# 2  2022-07-21    Andorra                        Moderate         55
# 3  2022-07-21     Angola  Unhealthy for Sensitive Groups        113
# 4  2022-07-21  Argentina                        Moderate         63

# %%
df.shape
# Out:
# (20968, 4)

# %%
df.columns
# Out:
# Index(['Date', 'Country', 'Status', 'AQI Value'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20968 entries, 0 to 20967
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       20968 non-null  object
#  1   Country    20968 non-null  object
#  2   Status     20968 non-null  object
#  3   AQI Value  20968 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 655.4+ KB

# %%
df.describe()
# Out:
#           AQI Value
# count  20968.000000
# mean      62.691959
# std       49.845802
# min        1.000000
# 25%       29.000000
# 50%       52.000000
# 75%       82.000000
# max      963.000000

# %%
df.isnull().sum()
# Out:
# Date         0
# Country      0
# Status       0
# AQI Value    0
# dtype: int64

# %%
# Remove duplicate rows if any
df = df.drop_duplicates()

# %%
# Convert categorical to numeric using one-hot encoding
df = pd.get_dummies(df, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# Convert back to DataFrame
df_scaled = pd.DataFrame(scaled_data, columns=df.columns)
df_scaled.head()
# Out:
#    AQI Value  Date_2022-07-22  Date_2022-07-23  Date_2022-07-24  \
# 0  -0.977304        -0.137591        -0.113311        -0.082879
# 1   0.047825        -0.137591        -0.113311        -0.082879
# 2  -0.153181        -0.137591        -0.113311        -0.082879
# 3   1.012652        -0.137591        -0.113311        -0.082879
# 4   0.007624        -0.137591        -0.113311        -0.082879
#
#    Date_2022-07-25  Date_2022-07-26  Date_2022-07-27  Date_2022-07-28  \
# 0        -0.082879        -0.113311        -0.082879        -0.082879
# 1        -0.082879        -0.113311        -0.082879        -0.082879
# 2        -0.082879        -0.113311        -0.082879        -0.082879
# 3        -0.082879        -0.113311        -0.082879        -0.082879
# 4        -0.082879        -0.113311        -0.082879        -0.082879
#
#    Date_2022-07-29  Date_2022-07-30  ...  Country_Uzbekistan  Country_Vatican  \
# ...

# %%
df.tail()
# Out:
#        AQI Value  Date_2022-07-22  Date_2022-07-23  Date_2022-07-24  \
# 20963         95            False            False            False
# 20964         24            False            False            False
# 20965         34            False            False            False
# 20966         26            False            False            False
# 20967         25            False            False            False
#
#        Date_2022-07-25  Date_2022-07-26  Date_2022-07-27  Date_2022-07-28  \
# 20963            False            False            False            False
# 20964            False            False            False            False
# 20965            False            False            False            False
# 20966            False            False            False            False
# 20967            False            False            False            False
#
#        Date_2022-07-29  Date_2022-07-30  ...  Country_Uzbekistan  \
# ...

# %%
df.isnull().mean()*100
# Out:
# AQI Value                                0.0
# Date_2022-07-22                          0.0
# Date_2022-07-23                          0.0
# Date_2022-07-24                          0.0
# Date_2022-07-25                          0.0
#                                         ...
# Status_Hazardous                         0.0
# Status_Moderate                          0.0
# Status_Unhealthy                         0.0
# Status_Unhealthy for Sensitive Groups    0.0
# Status_Very Unhealthy                    0.0
# Length: 297, dtype: float64

# %%
# Get descriptive statistics for the 'AQI Value' column
print(df['AQI Value'].describe())
# Out:
# count    20668.000000
# mean        62.620718
# std         49.751034
# min          1.000000
# 25%         29.000000
# 50%         52.000000
# 75%         82.000000
# max        963.000000
# Name: AQI Value, dtype: float64

# %%
import pandas as pd
import io
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Raw data from the CSV file
data = """Date,Country,Status,AQI Value
2022-07-21,Albania,Good,14
2022-07-21,Algeria,Moderate,65
2022-07-21,Andorra,Moderate,55
2022-07-21,Angola,Unhealthy for Sensitive Groups,113
2022-07-21,Argentina,Moderate,63
2022-07-21,Armenia,Moderate,76
2022-07-21,Australia,Moderate,56
2022-07-21,Austria,Good,45
2022-07-21,Azerbaijan,Good,12
2022-07-21,Bahrain,Unhealthy,165
2022-07-21,Bangladesh,Unhealthy for Sensitive Groups,141
2022-07-21,Belarus,Good,13
2022-07-21,Belgium,Moderate,61
2022-07-21,Belize,Good,28
2022-07-21,Bermuda,Good,12
2022-07-21,Bolivia,Good,9
2022-07-21,Bosnia and Herzegovina,Moderate,58
2022-07-21,Brazil,Moderate,67
2022-07-21,Brunei,Good,15
2022-07-21,Bulgaria,Good,26
2025-09-04,Poland,Moderate,73
2025-09-04,Portugal,Good,25
"""

# Load the dataset using io.StringIO to simulate reading from a file
df = pd.read_csv(io.StringIO(data))

# Convert the 'Date' column to a datetime object
df['Date'] = pd.to_datetime(df['Date'])

# Check for missing values
print("Missing values per column:")
print(df.isnull().sum())

# Feature Engineering: Extract time-based features
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['DayOfWeek'] = df['Date'].dt.dayofweek

# Separate features (X) and target (y)
X = df.drop(['Date', 'AQI Value'], axis=1)
y = df['AQI Value']

# Define categorical features to be one-hot encoded
categorical_features = ['Country']

# Ordinal Encoding for 'Status'
# The LabelEncoder will automatically assign an integer value based on alphabetical order.
le = LabelEncoder()
X['Status_encoded'] = le.fit_transform(X['Status'])

# One-hot Encoding for 'Country'
ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(), categorical_features)],
    remainder='passthrough'
)

# Apply the transformation and get the processed features
X_processed = ct.fit_transform(X)

print("\nProcessed features after encoding:")
print(X_processed.shape)
print("The number of columns has increased due to one-hot encoding for the 'Country' feature.")
# Out:
# Missing values per column:
# Date         0
# Country      0
# Status       0
# AQI Value    0
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\KASHISH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, Xs, n_samples)
#    1133                 ]
#    1134             except ValueError as e:
# -> 1135                 raise ValueError(
#    1136                     "For a sparse output, all columns should "
#
# c:\Users\KASHISH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                 else:
# ...

# %%
# Extract time-based features
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['DayOfWeek'] = df['Date'].dt.dayofweek

# %%
# Separate features (X) and target (y)
X = df.drop(['Date', 'AQI Value'], axis=1)
y = df['AQI Value']

# Define categorical features to be one-hot encoded
categorical_features = ['Country']

# Define the order for the ordinal 'Status' column
status_order = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

# Initialize LabelEncoder for the ordinal 'Status' column
le = LabelEncoder()
X['Status_encoded'] = le.fit_transform(X['Status'])

# Use ColumnTransformer for one-hot encoding 'Country'
ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(), categorical_features)],
    remainder='passthrough'
)

# %%
import pandas as pd
import io
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = """Date,Country,Status,AQI Value
2022-07-21,Albania,Good,14
...
2025-09-04,Portugal,Good,25
"""

# %%
df = pd.read_csv(io.StringIO(data))

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
print("Number of unparseable dates (NaNs):", df['Date'].isnull().sum())
# Out:
# Number of unparseable dates (NaNs): 0

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['DayOfWeek'] = df['Date'].dt.dayofweek

# %%
print("\nNew DataFrame Info:")
print(df.info())
# Out:
# New DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20968 entries, 0 to 20967
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       20968 non-null  datetime64[ns]
#  1   Country    20968 non-null  object
#  2   Status     20968 non-null  object
#  3   AQI Value  20968 non-null  int64
#  4   Year       20968 non-null  int32
#  5   Month      20968 non-null  int32
#  6   DayOfWeek  20968 non-null  int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 901.1+ KB
# None

# %%
X = df.drop(['Date', 'AQI Value'], axis=1)
y = df['AQI Value']

# %%
nominal_features = ['Country']
ordinal_features = ['Status']

# %%
status_order = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']
ordinal_transformer = OrdinalEncoder(categories=[status_order])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('nominal', OneHotEncoder(handle_unknown='ignore'), nominal_features),
        ('ordinal', ordinal_transformer, ordinal_features)
    ],
    remainder='passthrough'
)
X_processed = preprocessor.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print("Model Training Complete.")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Model Training Complete.
# Mean Squared Error (MSE): 168.91
# Root Mean Squared Error (RMSE): 13.00
# R-squared (R2): 0.93
